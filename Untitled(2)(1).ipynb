# %%
# !pip install wand

# %%
# !pip install magickwand

# %%
# !pip install imutils

# %%
import pytesseract
import cv2
import imutils

# %%
import os

path = 'C:/Users/saad.aftab/Desktop/OCR/images'
os.chdir(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-ff114c96eaf4> in <module>
#       2
#       3 path = 'C:/Users/saad.aftab/Desktop/OCR/images'
# ----> 4 os.chdir(path)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:/Users/saad.aftab/Desktop/OCR/images'

# %%
import glob
    
filelist = [ f for f in os.listdir(path) if f.endswith(".jpg") ]
for f in filelist:
    os.remove(os.path.join(path, f))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-c583cfdbfc34> in <module>
#       1 import glob
#       2
# ----> 3 filelist = [ f for f in os.listdir(path) if f.endswith(".jpg") ]
#       4 for f in filelist:
#       5     os.remove(os.path.join(path, f))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:/Users/saad.aftab/Desktop/OCR/images'

# %%
from wand.image import Image as Img

with Img(filename='C:/Users/saad.aftab/Desktop/OCR/test.pdf', resolution=300) as img:
    img.compression_quality = 99
    img.save(filename= path+'/sample_scan.jpg')
# Out:
# ---------------------------------------------------------------------------
# BlobError                                 Traceback (most recent call last)
# <ipython-input-7-ac2f916638ac> in <module>
#       1 from wand.image import Image as Img
#       2
# ----> 3 with Img(filename='C:/Users/saad.aftab/Desktop/OCR/test.pdf', resolution=300) as img:
#       4     img.compression_quality = 99
#       5     img.save(filename= path+'/sample_scan.jpg')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\wand\image.py in __init__(self, image, blob, file, filename, format, width, height, depth, background, resolution, pseudo)
#    6148                     self.read(blob=blob, resolution=resolution)
#    6149                 elif filename is not None:
# -> 6150                     self.read(filename=filename, resolution=resolution)
#    6151                 # clear the wand format, otherwise any subsequent call to
# ...

# %%
from PIL import Image
import pytesseract
import cv2

# %%
#get all images within a folder
image_list = []
for filename in glob.glob(path+'/*.jpg'): 
    im=Image.open(filename)
    image_list.append(im)

# %%
image_list

# %%
for i in range(0,len(image_list)):
    im = cv2.imread(path +'sample_scan-'+str(i)+'.jpg' , cv2.IMREAD_COLOR)

# %%
# !tesseract --help-oem

# %%
from PIL import Image
import pytesseract
final_text=' '
for i in range(0,len(image_list)):
 
    final_text = final_text+' ' + pytesseract.image_to_string(Image.open('sample_scan-'+str(i)+'.jpg'))

# %%
print(final_text)

# %%
# !tesseract --version

# %%
from imutils.object_detection import non_max_suppression
import pytesseract
import argparse
import numpy as np
import cv2

# %%
def decode_predictions(scores, geometry):
    # grab the number of rows and columns from the scores volume, then
    # initialize our set of bounding box rectangles and corresponding
    # confidence scores
    (numRows, numCols) = scores.shape[2:4]
    rects = []
    confidences = []
 
    # loop over the number of rows
    for y in range(0, numRows):
        # extract the scores (probabilities), followed by the
        # geometrical data used to derive potential bounding box
        # coordinates that surround text
        scoresData = scores[0, 0, y]
        xData0 = geometry[0, 0, y]
        xData1 = geometry[0, 1, y]
        xData2 = geometry[0, 2, y]
        xData3 = geometry[0, 3, y]
        anglesData = geometry[0, 4, y]
 
        # loop over the number of columns
        for x in range(0, numCols):
            # if our score does not have sufficient probability,
            # ignore it
            if scoresData[x] < 1:
                continue
 
            # compute the offset factor as our resulting feature
            # maps will be 4x smaller than the input image
            (offsetX, offsetY) = (x * 4.0, y * 4.0)
 
            # extract the rotation angle for the prediction and
            # then compute the sin and cosine
            angle = anglesData[x]
            cos = np.cos(angle)
            sin = np.sin(angle)
 
            # use the geometry volume to derive the width and height
            # of the bounding box
            h = xData0[x] + xData2[x]
            w = xData1[x] + xData3[x]
 
            # compute both the starting and ending (x, y)-coordinates
            # for the text prediction bounding box
            endX = int(offsetX + (cos * xData1[x]) + (sin * xData2[x]))
            endY = int(offsetY - (sin * xData1[x]) + (cos * xData2[x]))
            startX = int(endX - w)
            startY = int(endY - h)
 
            # add the bounding box coordinates and probability score
            # to our respective lists
            rects.append((startX, startY, endX, endY))
            confidences.append(scoresData[x])
 
    # return a tuple of the bounding boxes and associated confidences
    
    return (rects, confidences)

# %%
# load the input image and grab the image dimensions
# image = cv2.imread(path+'/sample_scan-0.jpg')
image = cv2.imread(r'C:\Users\shafiqa.iqbal\images\sample_scan-2.jpg')
orig = image.copy()
(origH, origW) = image.shape[:2]
 
# set the new width and height and then determine the ratio in change
# for both the width and height
(newW, newH) = (1280, 1920)
rW = origW/float(newW)
rH = origH/float(newH)

# resize the image and grab the new image dimensions
image = cv2.resize(image, (newW, newH))
(H, W) = image.shape[:2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5d6a3910e70e> in <module>
#       1 # load the input image and grab the image dimensions
#       2 # image = cv2.imread(path+'/sample_scan-0.jpg')
# ----> 3 image = cv2.imread(r'C:\Users\shafiqa.iqbal\images\sample_scan-2.jpg')
#       4 orig = image.copy()
#       5 (origH, origW) = image.shape[:2]
#
# NameError: name 'cv2' is not defined

# %%
 image.shape
# Out:
# (1920, 1280, 3)

# %%
layerNames = [
    "feature_fusion/Conv_7/Sigmoid",
    "feature_fusion/concat_3"]
 
# load the pre-trained EAST text detector
print("[INFO] loading EAST text detector...")
net = cv2.dnn.readNet(r'C:\Users\shafiqa.iqbal\images\frozen_east_text_detection.pb')
# Out:
# [INFO] loading EAST text detector...

# %%
rects=np.asarray(rects)
rects
# Out:
# array([[1087,   57, 1138,   82],
#        [1087,   57, 1137,   82],
#        [1087,   58, 1136,   82],
#        ...,
#        [ 297, 1731,  360, 1752],
#        [ 298, 1730,  360, 1751],
#        [ 382, 1727,  453, 1748]])

# %%
blob = cv2.dnn.blobFromImage(image, 1.0, (W, H),
    (123.68, 116.78, 103.94), swapRB=True, crop=False)
net.setInput(blob)
(scores, geometry) = net.forward(layerNames)
 
# decode the predictions, then  apply non-maxima suppression to
# suppress weak, overlapping bounding boxes
(rects, confidences) = decode_predictions(scores, geometry)
boxes = non_max_suppression(np.asarray(rects), probs=confidences)

# %%
boxes[0][0] = [800,  400, 1000,  900]

# %%
# initialize the list of results
results = []

# loop over the bounding boxes
for (startX, startY, endX, endY) in boxes:
	# scale the bounding box coordinates based on the respective
	# ratios
	startX = int(startX * rW)
	startY = int(startY * rH)
	endX = int(endX * rW)
	endY = int(endY * rH)

	# in order to obtain a better OCR of the text we can potentially
	# apply a bit of padding surrounding the bounding box -- here we
	# are computing the deltas in both the x and y directions
	dX = int((endX - startX) * 0.10)
	dY = int((endY - startY) * 0.10)

	# apply padding to each side of the bounding box, respectively
	startX = max(0, startX - dX)
	startY = max(0, startY - dY)
	endX = min(origW, endX + (dX * 2))
	endY = min(origH, endY + (dY * 2))

	# extract the actual padded ROI
	roi = orig[startY:endY, startX:endX]
    
    	# in order to apply Tesseract v4 to OCR text we must supply
	# (1) a language, (2) an OEM flag of 4, indicating that the we
	# wish to use the LSTM neural net model for OCR, and finally
	# (3) an OEM value, in this case, 7 which implies that we are
	# treating the ROI as a single line of text
	config = ("-l eng --oem 1 --psm 7")
	text = pytesseract.image_to_string(roi, config=config)

	# add the bounding box coordinates and OCR'd text to the list
	# of results
	results.append(((startX, startY, endX, endY), text))

# %%
results
# Out:
# [((1775, 1634, 1976, 1681), 'dryness, 6'),
#  ((1164, 2829, 1424, 2872), '+ weakness. F'),
#  ((2081, 1042, 2276, 1095), 'i skipping'),
#  ((938, 1638, 1204, 1685), '1, suspicious !e'),
#  ((419, 961, 590, 1002), 'Patient ¢'),
#  ((1680, 1634, 1788, 1676), 'skin,'),
#  ((1573, 2827, 1776, 2871), '$s present.'),
#  ((747, 105, 1046, 150), 'lf SURGERY'),
#  ((2012, 1919, 2150, 1974), 'lymph |'),
#  ((759, 1983, 986, 2028), '-persistent ir'),
#  ((565, 957, 734, 999), 'denies e'),
#  ((847, 1787, 1018, 1831), 'anxiety, ¢'),
#  ((2017, 1138, 2242, 1183), '; wheevina |'),
#  ((1401, 952, 1708, 996), 'e nosebleeds. nh'),
#  ((1758, 1388, 1998, 1423), 'weaknace 4'),
#  ((430, 1641, 594, 1683), 'Patient |'),
#  ((1529, 1639, 1650, 1674), 'eoelor'),
#  ((1740, 1829, 2006, 1872), '> axcessive hi'),
#  ((1968, 1384, 2080, 1436), 'joint :'),
#  ((588, 1153, 744, 1197), 'Patient ¢'),
#  ((688, 1836, 846, 1879), '‘ danies |'),
#  ((1920, 99, 2158, 152), 'February 4'),
# ...

# %%
# sort the results bounding box coordinates from top to bottom
results = sorted(results, key=lambda r:r[0][1])

# loop over the results
for ((startX, startY, endX, endY), text) in results:
    # display the text OCR'd by Tesseract
    print("OCR TEXT")
    print("========")
    print("{}\n".format(text))
    
    # strip out non-ASCII text so we can draw the text on the image
    # using OpenCV, then draw the text and a bounding box surrounding
    # the text region of the input image
    text = "".join([c if ord(c) < 128 else "" for c in text]).strip()

    output = orig.copy()
    cv2.rectangle(output, (startX, startY), (endX, endY),(0, 0, 255), 2)
    cv2.putText(output, text, (startX, startY - 20),cv2.FONT_HERSHEY_SIMPLEX, 1.2, (0, 0, 255), 3)
 
    # show the output image
    imS = cv2.resize(output, (1920, 1080))
    cv2.imshow("Text Detection", imS)
    cv2.waitKey(0)
# Out:
# OCR TEXT
# ...
# 2019
#
# OCR TEXT
# ...
# February 4
#
# OCR TEXT
# ...
# CfAPRPDIO OBY A
#
# OCR TEXT
# ...
# lf SURGERY
#
# OCR TEXT
# ...
# AND |
#
# OCR TEXT
# ...
# icCvVs
#
# OCR TEXT
# ...
# 1 Avenue §S
#
# OCR TEXT
# ...
# Christine A
#
# OCR TEXT
# ...
# Suite
#
# OCR TEXT
# ...
# 100
#
# OCR TEXT
# ...
# 1700 (
#
# OCR TEXT
# ...
# 36205
#
# OCR TEXT
# ...
# Anniston, #
#
# OCR TEXT
# ...
# , Aabama :
#
# OCR TEXT
# ...
# PH: :
#
# OCR TEXT
# ...
# 8624
#
# OCR TEXT
# ...
# ?56-
#
# OCR TEXT
# ...
# FAX:
#
# OCR TEXT
# ...
# -7 38-1
#
# OCR TEXT
# ...
# -237-
#
# OCR TEXT
# ...
# 154
#
# OCR TEXT
# ...
# ?56-:
#
# OCR TEXT
# ...
# None
#
# OCR TEXT
# ...
# -356239R36R :N
#
# OCR TEXT
# ...
# Oneal
#
# OCR TEXT
# ...
# None :
#
# OCR TEXT
# ...
# CELL: 2
#
# OCR TEXT
# ...
# Dock I
#
# OCR TEXT
# ...
# 29207
#
# OCR TEXT
# ...
# 29763
#
# OCR TEXT
# ...
# ‘BCBS |
#
# OCR TEXT
# ...
# Gro;
#
# OCR TEXT
# ...
# 19/1875
#
# OCR TEXT
# ...
# Ins:
#
# OCR TEXT
# ...
# *E acal ¢
#
# OCR TEXT
# ...
# Male
#
# OCR TEXT
# ...
# Al
#
# OCR TEXT
# ...
# DOB:
#
# OCR TEXT
# ...
# F Systems
#
# OCR TEXT
# ...
# of |
#
# OCR TEXT
# ...
# Review <
#
# OCR TEXT
# ...
# weight ¢
#
# OCR TEXT
# ...
# Positive f
#
# OCR TEXT
# ...
# gain.
#
# ...
